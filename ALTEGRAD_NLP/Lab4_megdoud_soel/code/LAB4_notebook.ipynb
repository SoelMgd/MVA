# %%
# !pip install -r /content/ALTEGRAD_LAB4/code/RequirementsFiles/lab4-requirements.txt

# %% [markdown]
# ## Part 1. Tasks 1 and 2.

# %%
# !python /content/ALTEGRAD_LAB4/code/part1/code_lab_exploration.py
# Out:
# Task 1.
#
# Number of nodes: 9877
# Number of edges: 25998
#
# Task 2.
#
# Number of connected components: 429
# Number of nodes in the biggest connected component: 8638
# Number of edges in the biggest connected component: 24827
# Ratio of nodes from the biggest connected component: 87.4557%
# Ratio of edges from the biggest connected component: 95.4958%

# %% [markdown]
# ## Part 2. Task 3 to 6

# %%
# !python /content/ALTEGRAD_LAB4/code/part2/code_lab_community_detection.py
# Out:
# Task 4.
#
# ...

# %% [markdown]
# ## Part 3.
# Tasks 7 to 10

# %%
#!pip install torch_geometric

# %%
# !python /content/ALTEGRAD_LAB4/code/part3/code_lab_graph_classification.py
# Out:
# Accuracy for Shortest Path Kernel: 0.8947
# Accuracy for Graphlet Kernel: 0.8158

# %% [markdown]
# Tasks 11 to 14

# %%
# %pip install grakel

# %%
# !python /content/ALTEGRAD_LAB4/code/part3/code_grakel.py
# Out:
# Vocabulary size:  7151
# Example of graph-of-words representation of document
# Figure(640x480)
# Accuracy using WL subtree kernel: 0.9540
# Accuracy using Vertex Histogram kernel: 0.9720
